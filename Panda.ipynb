# %%
import pandas 
pandas.__version__
# Out:
# '1.0.5'

# %%
import numpy as np
import pandas as pd
series=pd.Series([11,9,1998,2000])
series
# Out:
# 0      11
# 1       9
# 2    1998
# 3    2000
# dtype: int64

# %%
series.values
# Out:
# array([  11,    9, 1998, 2000])

# %%
series.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
kgs=pd.Series([10,20,30,40],
 index=['dal','rice','ragi','wheat'])
kgs
# Out:
# dal      10
# rice     20
# ragi     30
# wheat    40
# dtype: int64

# %%
kgs['dal']
# Out:
# 10

# %%
kgs[3]
# Out:
# 40

# %%
kgs.name="groceries"
kgs.index.name="items"
kgs
# Out:
# items
# dal      10
# rice     20
# ragi     30
# wheat    40
# Name: groceries, dtype: int64

# %%
np.log(kgs)
# Out:
# items
# dal      2.302585
# rice     2.995732
# ragi     3.401197
# wheat    3.688879
# Name: groceries, dtype: float64

# %%
kgs[kgs>20]
# Out:
# items
# ragi     30
# wheat    40
# Name: groceries, dtype: int64

# %%
items={'Dal':10,'Rice':20,'Ragi':30,'Wheat':40}
print(items)
pd.Series(items)
# Out:
# {'Dal': 10, 'Rice': 20, 'Ragi': 30, 'Wheat': 40}
# Dal      10
# Rice     20
# Ragi     30
# Wheat    40
# dtype: int64

# %%
data={"Provinence":['SD','DL','FD','NM'],
      "year":[2000,2002,2004,2006],
      "litreacy":[0.2,0.1,0.4,0.5]}
print(data)
data=pd.DataFrame(data)
data
# Out:
# {'Provinence': ['SD', 'DL', 'FD', 'NM'], 'year': [2000, 2002, 2004, 2006], 'litreacy': [0.2, 0.1, 0.4, 0.5]}
#   Provinence  year  litreacy
# 0         SD  2000       0.2
# 1         DL  2002       0.1
# 2         FD  2004       0.4
# 3         NM  2006       0.5

# %%
d=pd.DataFrame(data,columns=["year","litreacy","Provinence"])
d
# Out:
#    year  litreacy Provinence
# 0  2000       0.2         SD
# 1  2002       0.1         DL
# 2  2004       0.4         FD
# 3  2006       0.5         NM

# %%
d['nonsesnse']=d.year/d.litreacy
d
# Out:
#    year  litreacy Provinence  nonsesnse
# 0  2000       0.2         SD    10000.0
# 1  2002       0.1         DL    20020.0
# 2  2004       0.4         FD     5010.0
# 3  2006       0.5         NM     4012.0

# %%
d['series']=pd.Series(range(4),index=[0,1,2,3])
d
# Out:
#    year  litreacy Provinence  nonsesnse  series
# 0  2000       0.2         SD    10000.0       0
# 1  2002       0.1         DL    20020.0       1
# 2  2004       0.4         FD     5010.0       2
# 3  2006       0.5         NM     4012.0       3

# %%
d['series']=pd.Series(range(5),index=[0,1,2,3])
d
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-5f41433cbe1f> in <module>()
# ----> 1 d['series']=pd.Series(range(5),index=[0,1,2,3])
#       2 d
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     290                     if len(index) != len(data):
#     291                         raise ValueError(
# --> 292                             f"Length of passed values is {len(data)}, "
#     293                             f"index implies {len(index)}."
#     294                         )
#
# ValueError: Length of passed values is 5, index implies 4.

# %%
d.to_dict()
# Out:
# {'Provinence': {0: 'SD', 1: 'DL', 2: 'FD', 3: 'NM'},
#  'litreacy': {0: 0.2, 1: 0.1, 2: 0.4, 3: 0.5},
#  'nonsesnse': {0: 10000.0, 1: 20020.0, 2: 5010.0, 3: 4012.0},
#  'series': {0: 0, 1: 1, 2: 2, 3: 3},
#  'year': {0: 2000, 1: 2002, 2: 2004, 3: 2006}}

# %%
pd.DataFrame(d.to_dict())
# Out:
#    year  litreacy Provinence  nonsesnse  series
# 0  2000       0.2         SD    10000.0       0
# 1  2002       0.1         DL    20020.0       1
# 2  2004       0.4         FD     5010.0       2
# 3  2006       0.5         NM     4012.0       3

# %%
d=[{"a":i,"b":10*i}for i in range(9)]
d=pd.DataFrame(d)
d
# Out:
#    a   b
# 0  0   0
# 1  1  10
# 2  2  20
# 3  3  30
# 4  4  40
# 5  5  50
# 6  6  60
# 7  7  70
# 8  8  80

# %%
pd.DataFrame([{'a':1,'b':2,},{'b':3,'c':5}])
# Out:
#      a  b    c
# 0  1.0  2  NaN
# 1  NaN  3  5.0

# %%
pd.DataFrame(np.random.randint(1,9),
   columns=['doll','cartoon'],
   index=['barbie','tom'])
# Out:
#         doll  cartoon
# barbie     5        5
# tom        5        5

# %%
a=pd.Index([1,2,3,4,5,6,7])
a
# Out:
# Int64Index([1, 2, 3, 4, 5, 6, 7], dtype='int64')

# %%
a[2]
# Out:
# 3

# %%
a[::-1]
# Out:
# Int64Index([7, 6, 5, 4, 3, 2, 1], dtype='int64')

# %%
print(a.size,a.ndim,a.shape)
# Out:
# 7 1 (7,)

# %%
a[1]=0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-2226a346ff5c> in <module>()
# ----> 1 a[1]=0
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    3908
#    3909     def __setitem__(self, key, value):
# -> 3910         raise TypeError("Index does not support mutable operations")
#    3911
#    3912     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
r = np.random.RandomState(12)
s = pd.Series(r.randint(0, 1, 4))
s
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# dtype: int64

# %%
np.exp(s)
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# dtype: float64

# %%
 d=pd.DataFrame({"Province": ["a", "b", "c"], "Population": ["10k", "20k", "30k"]})
d
# Out:
#   Province Population
# 0        a        10k
# 1        b        20k
# 2        c        30k

# %%
d3 = pd.DataFrame({"province": ["a", "b"], "Population": ["10", "20"]})
d3
d.merge(d3, right_on='province', left_on='Province')
# Out:
#   Province Population_x province Population_y
# 0        a          10k        a           10
# 1        b          20k        b           20

# %%
serie_a = pd.Series([np.nan, 2.5, np.nan, 3.5, 4.5, np.nan],
                     index=['f', 'e', 'd', 'c', 'b', 'a'])
serie_b = pd.Series(np.arange(len(serie_a), dtype=np.float64),
                 index=['f', 'e', 'd', 'c', 'b', 'a'])
serie_b
# Out:
# f    0.0
# e    1.0
# d    2.0
# c    3.0
# b    4.0
# a    5.0
# dtype: float64

# %%
pd.Series(np.where(pd.isnull(serie_a), serie_b, serie_a), index=serie_a.index)
# Out:
# f    0.0
# e    2.5
# d    2.0
# c    3.5
# b    4.5
# a    5.0
# dtype: float64

# %%
serie_a.combine_first(serie_b)
# Out:
# f    0.0
# e    2.5
# d    2.0
# c    3.5
# b    4.5
# a    5.0
# dtype: float64
