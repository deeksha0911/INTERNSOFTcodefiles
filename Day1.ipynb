# %%
#INTEGERS
x=1
type(x)
# Out:
# int

# %%
#float
x=1.2
type(x)
# Out:
# float

# %%
#Boolean
b1=True
b2=False
type(b1)
# Out:
# bool

# %%
#String
name1='Your Name'
type(name1)
# Out:
# str

# %%
#complex
x=1.0-2.0j
type(x)
# Out:
# complex

# %%
print(x)
# Out:
# (1-2j)

# %%
print(x.real,x.imag)
# Out:
# 1.0 -2.0

# %%
#variable
tenth=10
two=2
print(tenth)
two
# Out:
# 10
# 2

# %%
ten=10
ten
# Out:
# 10

# %%
ten='ten'
ten
# Out:
# 'ten'

# %%
'Day' + str(1)
# Out:
# 'Day1'

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
True is False
# Out:
# False

# %%
not True
# Out:
# False

# %%
'a' is 'a'
# Out:
# True

# %%
not False
# Out:
# True

# %%
i=3
if i<3:
  print('less than 3')
elif i<5:
  print('less than 5')
else:
  print('5 or more')
# Out:
# less than 5

# %%
a=list()
a
# Out:
# []

# %%
a=[]
a

# %%
b=['a','b','c']
print(b)
type(b)
# Out:
# ['a', 'b', 'c']
# list

# %%
l=[1,2]
print(l)
l.append('b')
print(l)
l.insert(1,56)
l
for i in l:
  print(i)
# Out:
# [1, 2]
# [1, 2, 'b']
# 1
# 56
# 2
# b

# %%
#list of numbers
numbers=[6,5,3,8,4,2,5,9]
sum=0
for i in numbers:
  sum=sum+i
print("the sum is",sum)
sum
# Out:
# the sum is 42
# 42

# %%
digits=[1,2,3,4,5]
for i in digits:
  print(i)
else:
  print("NO ITEMS LEFT")
# Out:
# 1
# 2
# 3
# 4
# 5
# NO ITEMS LEFT

# %%
gener=['jazz','rock','pop','sapna']
for i in range(len(gener)):
  print("I LIKE ",gener[i])
# Out:
# I LIKE  jazz
# I LIKE  rock
# I LIKE  pop
# I LIKE  sapna

# %%
for val in 'harshitha':
  if val=='i':
    break
  print(val)
print("THE END")
# Out:
# h
# a
# r
# s
# h
# THE END

# %%
age=int(input("What is ur age"))
print("your age is",age)
type(age)
# Out:
# What is ur age24
# your age is 24
# int

# %%
name=input("name")
print("it is nice talking to you "+name+"!")
age=int(input("enter your age"))
print("HEY"+name+"you are already"+age+"!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     490         """
# --> 491         parts = [self.recv(flags, copy=copy, track=track)]
#     492         # have first part already, only loop while more to receive
#
# ...
