# %%
#single word
str='hello'
print(str)
# Out:
# 'hello'

# %%
"HAI this is Deeksha"
# Out:
# 'HAI this is Deeksha'

# %%
'hai'
# Out:
# 'hai'

# %%
"I'm Deeksha"
# Out:
# "I'm Deeksha"

# %%
'I'm Deeksha'
# Out:
#   File "<ipython-input-6-69161ffd9ce1>", line 1
#     'I'm Deeksha'
#        ^
# SyntaxError: invalid syntax

# %%
"What\'s your name"
# Out:
# "What's your name"

# %%
"HAI"
'hai'
# Out:
# 'hai'

# %%
s="Welcome to Python"
s
s[0]
# Out:
# 'W'

# %%
s[-1]
# Out:
# 'n'

# %%
s[1:]
# Out:
# 'elcome to Python'

# %%
s[:]
# Out:
# 'Welcome to Python'

# %%
s[::1]
# Out:
# 'Welcome to Python'

# %%
s[-1]
# Out:
# 'n'

# %%
s[::2]
# Out:
# 'Wloet yhn'

# %%
s[::-1]
# Out:
# 'nohtyP ot emocleW'

# %%
s="Welcome"
print(s)
s=s+"to Python prgming"
print(s)
# Out:
# Welcome
# Welcometo Python prgming

# %%
a=123
print(a)
a*30
# Out:
# 123
# 3690

# %%
s="Hello World"
s.upper()
# Out:
# 'hello world'

# %%
s.lower()
# Out:
# 'hello world'

# %%
s.split()
# Out:
# ['Hello', 'World']

# %%
s.split('o')
# Out:
# ['Hell', ' W', 'rld']

# %%
'HELLO:{}'.format({'Deeksha'})
# Out:
# "HELLO:{'Deeksha'}"

# %%
print(s)
# Out:
# Hello World

# %%
s.count('o')
# Out:
# 2

# %%
s.find('o')
# Out:
# 4

# %%
s.center(30,'*')
# Out:
# '*********Hello World**********'

# %%
'hello\thi'.expandtabs()
# Out:
# 'hello   hi'

# %%
'hello\t hi'.exapndtabs()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-c9174668fd90> in <module>()
# ----> 1 'hello\t hi'.exapndtabs()
#
# AttributeError: 'str' object has no attribute 'exapndtabs'

# %%
s='hello'
s.isalnum()
# Out:
# True

# %%
s.isalpha()
# Out:
# True

# %%
s.islower()
# Out:
# True

# %%
s.isspace()
# Out:
# False

# %%
s.istitle()
# Out:
# False

# %%
s.isupper()
# Out:
# False

# %%
s.endswith('o')
# Out:
# True

# %%
s[-1]=='o'
# Out:
# True

# %%
s.split('e')
# Out:
# ['h', 'llo']

# %%
s.partition('e')
# Out:
# ('h', 'e', 'llo')

# %%
s
# Out:
# 'hello'

# %%
my_list=['one','two','three',4,5]
my_list[0]
# Out:
# 'one'

# %%
my_list[1:]
# Out:
# ['two', 'three', 4, 5]

# %%
my_list[:3]
# Out:
# ['one', 'two', 'three']

# %%
my_list+['new ele']
# Out:
# ['one', 'two', 'three', 4, 5, 'new ele']

# %%
print(my_list)
# Out:
# ['one', 'two', 'three', 4, 5]

# %%
my_list*2
# Out:
# ['one', 'two', 'three', 4, 5, 'one', 'two', 'three', 4, 5]

# %%
my_list
# Out:
# ['one', 'two', 'three', 4, 5]

# %%
['new ele']+my_list
# Out:
# ['new ele', 'one', 'two', 'three', 4, 5]

# %%
#pop
l=[1,2,3,'append me']
l.pop(0)
# Out:
# 1

# %%
l
# Out:
# [2, 3, 'append me']

# %%
l[123]

# %%
new_list=['a','b','c','e']
new_list.reverse()

# %%
new_list.sort()

# %%
lst1=[1,2,3]
lst2=[4,5,6]
lst3=[7,8,9]
matrix=[lst1,lst2,lst3]
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
matrix[1][1]
# Out:
# 5

# %%
l=[1,2,3]
l.append(4)
l
# Out:
# [1, 2, 3, 4]

# %%
l.count(10)
# Out:
# 0

# %%
l.count(1)
# Out:
# 1

# %%
x=[1,2,3]
x.append([4,5])
print(x)
# Out:
# [1, 2, 3, [4, 5]]

# %%
print(x)
# Out:
# [1, 2, 3, [4, 5]]

# %%
x=[1,2,3,4]
x.extend([4,5])
print(x)
# Out:
# [1, 2, 3, 4, 4, 5]

# %%
print(l)
# Out:
# [1, 2, 3, 4]

# %%
l.index(2)
# Out:
# 1

# %%
l.index(12)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-da9218b18168> in <module>()
# ----> 1 l.index(12)
#
# ValueError: 12 is not in list

# %%
print(l)
# Out:
# [1, 2, 3, 4]

# %%
l.insert(2,'*')
print(l)
# Out:
# [1, 2, '*', 3, 4]

# %%
#pop
ele=l.pop()
l
# Out:
# [1, 2, '*']

# %%
ele
# Out:
# 3

# %%
l=[1,2,3,4,5,3]
l.remove(3)
l
# Out:
# [1, 2, 4, 5, 3]

# %%
l=[1,2,3,5,4,6,7,7]
l.sort()
print(l)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 7]

# %%
print(l)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 7]
